# %%
# !pip install pydub

import os
import pandas as pd
import numpy as np 
import seaborn as sns
from tqdm import tqdm

from pydub import AudioSegment
from IPython.display import Audio

import librosa
import librosa.display
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.8/dist-packages (0.25.1)

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/train_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_train = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_train.shape)
df_train.sample(5)
# Out:
# (974, 2)
#                                                   path class_name
# 174  /content/drive/MyDrive/Bird/dataset/whole_data...       duck
# 62   /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl
# 830  /content/drive/MyDrive/Bird/dataset/whole_data...    lapwing
# 893  /content/drive/MyDrive/Bird/dataset/whole_data...        owl
# 926  /content/drive/MyDrive/Bird/dataset/whole_data...        owl

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_train['class_label'] = df_train.apply(name_to_label, axis=1)
df_train.sample(5)
# Out:
#                                                   path class_name  class_label
# 742  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe            9
# 347  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel            0
# 824  /content/drive/MyDrive/Bird/dataset/whole_data...    lapwing            5
# 48   /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 276  /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/validation_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_test = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_test.shape)
df_test.sample(5)
# Out:
# (104, 2)
#                                                  path class_name
# 61  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 9   /content/drive/MyDrive/Bird/dataset/whole_data...        owl
# 29  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway
# 22  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway
# 15  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_test['class_label'] = df_test.apply(name_to_label, axis=1)
df_test.sample(5)
# Out:
#                                                   path class_name  class_label
# 103  /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2
# 9    /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6
# 98   /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2
# 64   /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 4    /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6

# %%
# !pip install pydub

import os
import pandas as pd
import numpy as np 
import seaborn as sns
from tqdm import tqdm

from pydub import AudioSegment
from IPython.display import Audio

import librosa
import librosa.display
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.8/dist-packages (0.25.1)

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/train_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_train = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_train.shape)
df_train.sample(5)
# Out:
# (974, 2)
#                                                   path class_name
# 661  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway
# 502  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay
# 353  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 313  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 783  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_train['class_label'] = df_train.apply(name_to_label, axis=1)
df_train.sample(5)
# Out:
#                                                   path class_name  class_label
# 104  /content/drive/MyDrive/Bird/dataset/whole_data...       duck            3
# 692  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe            9
# 510  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 339  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel            0
# 383  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel            0

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/validation_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_test = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_test.shape)
df_test.sample(5)
# Out:
# (104, 2)
#                                                  path class_name
# 89  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl
# 66  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay
# 55  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 9   /content/drive/MyDrive/Bird/dataset/whole_data...        owl
# 37  /content/drive/MyDrive/Bird/dataset/whole_data...    sparrow

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_test['class_label'] = df_test.apply(name_to_label, axis=1)
df_test.sample(5)
# Out:
#                                                  path class_name  class_label
# 77  /content/drive/MyDrive/Bird/dataset/whole_data...    lapwing            5
# 1   /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6
# 33  /content/drive/MyDrive/Bird/dataset/whole_data...    sparrow            8
# 90  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 41  /content/drive/MyDrive/Bird/dataset/whole_data...       duck            3

# %%
#train set
X_train = df_train['path']
y_train = df_train['class_label']

#test set
X_test = df_test['path']
y_test = df_test['class_label']

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((974,), (974,), (104,), (104,))

# %%
#getting mfcc features for all the data points in test and train

def get_spec(path):
    y, sr = librosa.load(path)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    return S

# %%
# train data
temp = []
label = []
for i in tqdm(range(len(X_train))):
  audio_path = X_train.iloc[i]
  mfcc = get_spec(audio_path)
  mfcc = np.resize(mfcc, (65, 40,))
  temp.append(mfcc)
  label.append(y_train.iloc[i])

X_train_processed = np.asarray(temp)
y_train = np.asarray(label)

X_train_processed.shape, y_train.shape
# Out:
# 100%|██████████| 974/974 [04:04<00:00,  3.99it/s]
# ((974, 65, 40), (974,))

# %%
#test data
temp = []
label = []

for i in tqdm(range(len(X_test))):
  audio_path = X_test.iloc[i]
  mfcc = get_spec(audio_path)
  mfcc = np.resize(mfcc, (65, 40))
  temp.append(mfcc)
  label.append(y_test.iloc[i])

X_test_processed = np.asarray(temp)
y_test = np.asarray(label)

X_test_processed.shape, y_test.shape
# Out:
# 100%|██████████| 104/104 [00:31<00:00,  3.30it/s]
# ((104, 65, 40), (104,))

# %% [markdown]
# #### Modelling

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
import keras.backend as K

tf.keras.backend.clear_session()

# %%
# Add attention layer to the deep learning network
class attention(layers.Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)
 
    def build(self,input_shape):
        self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1), 
                               initializer='random_normal', trainable=True)
        self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1), 
                               initializer='zeros', trainable=True)        
        super(attention, self).build(input_shape)
 
    def call(self,x):
        # Alignment scores. Pass them through tanh function
        e = K.tanh(K.dot(x,self.W)+self.b)
        # Remove dimension of size 1
        e = K.squeeze(e, axis=-1)   
        # Compute the weights
        alpha = K.softmax(e)
        # Reshape to tensorFlow format
        alpha = K.expand_dims(alpha, axis=-1)
        # Compute the context vector
        context = x * alpha
        context = K.sum(context, axis=1)
        return context

# %%
#Create model

#input
input = layers.Input(shape=(65,40), name='input_layer')

#cnn
x = layers.Conv1D(128, (3,), activation='relu')(input)
a1 = attention()(x)
 
#lstm
x = layers.LSTM(128, return_sequences = True)(x)
a2 = attention()(x)

#attention 
x = layers.Concatenate()([a1, a2])

#dense
x = layers.Dense(128,'relu')(x)
x = layers.Dense(64,'relu')(x)
x = layers.Dense(32,'relu')(x)

#output
output = layers.Dense(10, 'softmax', name='output_layer')(x)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 65, 40)]     0           []
#
#  conv1d_2 (Conv1D)              (None, 63, 128)      15488       ['input_layer[0][0]']
#
#  lstm_2 (LSTM)                  (None, 63, 128)      131584      ['conv1d_2[0][0]']
#
#  attention_4 (attention)        (None, 128)          191         ['conv1d_2[0][0]']
#
#  attention_5 (attention)        (None, 128)          191         ['lstm_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 256)          0           ['attention_4[0][0]',
#                                                                   'attention_5[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['concatenate_2[0][0]']
#
#  dense_7 (Dense)                (None, 64)           8256        ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 32)           2080        ['dense_7[0][0]']
#
#  output_layer (Dense)           (None, 10)           330         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 191,016
# Trainable params: 191,016
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#compile
ls = tf.keras.losses.SparseCategoricalCrossentropy()
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(adam, ls, metrics='accuracy')

#fitting
history = model.fit(X_train_processed, y_train, 
                    validation_data = (X_test_processed, y_test),
                    epochs = 20)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 8s 157ms/step - loss: 2.3211 - accuracy: 0.1160 - val_loss: 2.3089 - val_accuracy: 0.1635
# Epoch 2/20
# 31/31 [==============================] - 4s 130ms/step - loss: 2.2792 - accuracy: 0.1735 - val_loss: 2.2694 - val_accuracy: 0.1731
# Epoch 3/20
# 31/31 [==============================] - 4s 127ms/step - loss: 2.2573 - accuracy: 0.1879 - val_loss: 2.2348 - val_accuracy: 0.2212
# Epoch 4/20
# 31/31 [==============================] - 4s 128ms/step - loss: 2.2292 - accuracy: 0.1971 - val_loss: 2.2006 - val_accuracy: 0.2212
# Epoch 5/20
# 31/31 [==============================] - 4s 126ms/step - loss: 2.1954 - accuracy: 0.1992 - val_loss: 2.1596 - val_accuracy: 0.2115
# Epoch 6/20
# 31/31 [==============================] - 4s 140ms/step - loss: 2.1621 - accuracy: 0.2136 - val_loss: 2.1265 - val_accuracy: 0.2019
# Epoch 7/20
# 31/31 [==============================] - 4s 127ms/step - loss: 2.1340 - accuracy: 0.2197 - val_loss: 2.0994 - val_accuracy: 0.2115
# Epoch 8/20
# 31/31 [==============================] - 4s 130ms/step - loss: 2.1052 - accuracy: 0.2556 - val_loss: 2.0823 - val_accuracy: 0.2308
# Epoch 9/20
# 31/31 [==============================] - 4s 127ms/step - loss: 2.0776 - accuracy: 0.2690 - val_loss: 2.0430 - val_accuracy: 0.2788
# Epoch 10/20
# 31/31 [==============================] - 4s 125ms/step - loss: 2.0452 - accuracy: 0.2690 - val_loss: 1.9991 - val_accuracy: 0.2981
# Epoch 11/20
# 31/31 [==============================] - 4s 125ms/step - loss: 2.0047 - accuracy: 0.2803 - val_loss: 1.9481 - val_accuracy: 0.3942
# Epoch 12/20
# 31/31 [==============================] - 4s 126ms/step - loss: 1.9602 - accuracy: 0.2875 - val_loss: 1.9107 - val_accuracy: 0.3365
# Epoch 13/20
# 31/31 [==============================] - 4s 127ms/step - loss: 1.9133 - accuracy: 0.3008 - val_loss: 1.8411 - val_accuracy: 0.3173
# Epoch 14/20
# 31/31 [==============================] - 5s 155ms/step - loss: 1.8523 - accuracy: 0.3060 - val_loss: 1.8000 - val_accuracy: 0.3846
# Epoch 15/20
# 31/31 [==============================] - 4s 130ms/step - loss: 1.8122 - accuracy: 0.3049 - val_loss: 1.7705 - val_accuracy: 0.3846
# Epoch 16/20
# 31/31 [==============================] - 4s 127ms/step - loss: 1.7464 - accuracy: 0.3357 - val_loss: 1.7882 - val_accuracy: 0.3558
# Epoch 17/20
# 31/31 [==============================] - 4s 126ms/step - loss: 1.7147 - accuracy: 0.3491 - val_loss: 1.7251 - val_accuracy: 0.4038
# Epoch 18/20
# 31/31 [==============================] - 4s 125ms/step - loss: 1.6656 - accuracy: 0.3737 - val_loss: 1.7139 - val_accuracy: 0.4615
# Epoch 19/20
# 31/31 [==============================] - 4s 127ms/step - loss: 1.6081 - accuracy: 0.4199 - val_loss: 1.6797 - val_accuracy: 0.4615
# Epoch 20/20
# 31/31 [==============================] - 4s 124ms/step - loss: 1.5953 - accuracy: 0.4240 - val_loss: 1.6314 - val_accuracy: 0.5288

# %% [markdown]
# #### Predictions

# %%
# !pip install pydub

import os 
from multiprocessing import Pool

import pandas as pd
import numpy as np

from sklearn.metrics import f1_score
from scipy.sparse import lil_matrix

import tensorflow as tf 
from tqdm import tqdm

import librosa
from pydub import AudioSegment
from pydub.utils import make_chunks
from IPython.display import Audio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.8/dist-packages (0.25.1)

# %%
#assigning numerical class labels to each bird species

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
             'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

########################################################

def get_class_labels(r):
  x = r['class_name']
  label_names = x.split('_')

  label_nums=[]
  for l in label_names:
    indx = cls_label[l]
    label_nums.append(indx)

  return label_nums

# %%
# creating the dataframe which has path to wav file and it's label
# 2 species test dataset
label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/mix_2'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_mix_2 = pd.DataFrame({'path': path,
                         'class_name': label})

df_mix_2['class_label'] = df_mix_2.apply(get_class_labels, axis=1)

print(df_mix_2.shape)
df_mix_2.sample(5)
# Out:
# (334, 3)
#                                                   path         class_name  \
# 91   /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel_bluejay
# 20   /content/drive/MyDrive/Bird/dataset/whole_data...        owl_sparrow
# 27   /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl_bluejay
# 165  /content/drive/MyDrive/Bird/dataset/whole_data...       duck_bluejay
# 53   /content/drive/MyDrive/Bird/dataset/whole_data...         owl_goaway
#
#     class_label
# 91       [0, 1]
# 20       [6, 8]
# 27       [7, 1]
# 165      [3, 1]
# 53       [6, 4]

# %%
# 3 species test dataset 
label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/mix_3'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_mix_3 = pd.DataFrame({'path': path,
                         'class_name': label})

df_mix_3['class_label'] = df_mix_3.apply(get_class_labels, axis=1)

print(df_mix_3.shape)
df_mix_3.sample(5)
# Out:
# (100, 3)
#                                                  path  \
# 66  /content/drive/MyDrive/Bird/dataset/whole_data...
# 16  /content/drive/MyDrive/Bird/dataset/whole_data...
# 14  /content/drive/MyDrive/Bird/dataset/whole_data...
# 70  /content/drive/MyDrive/Bird/dataset/whole_data...
# 53  /content/drive/MyDrive/Bird/dataset/whole_data...
#
#                   class_name class_label
# 66         crow_sparrow_duck   [2, 8, 3]
# 16    bluejay_woodpeewe_crow   [1, 9, 2]
# 14    bluejay_woodpeewe_crow   [1, 9, 2]
# 70  goaway_sparrow_Asiankoel   [4, 8, 0]
# 53         duck_sparrow_crow   [3, 8, 2]

# %%
# whole test data i.e mixture of both 2 and 3 species audio files
df = pd.concat([df_mix_2, df_mix_3], ignore_index = True)
df.sample(5)
# Out:
#                                                   path         class_name  \
# 106  /content/drive/MyDrive/Bird/dataset/whole_data...          duck_crow
# 387  /content/drive/MyDrive/Bird/dataset/whole_data...  duck_sparrow_crow
# 309  /content/drive/MyDrive/Bird/dataset/whole_data...     lapwing_goaway
# 253  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe_lapwing
# 241  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe_lapwing
#
#     class_label
# 106      [3, 2]
# 387   [3, 8, 2]
# 309      [5, 4]
# 253      [9, 5]
# 241      [9, 5]

# %%
# ref: https://www.kaggle.com/code/arailly/multi-label-f-beta-score/notebook

# metrics function

def label_to_sm(labels, n_classes):
    sm = lil_matrix((len(labels), n_classes))
    for i, label in enumerate(labels):
        sm[i, label] = 1  #eg: sm[0, [2,3]] = 1
    return sm

###############################################

def get_f1_score(y_true, y_pred):
  y_true_sm = label_to_sm(labels=y_true, n_classes=10)
  y_pred_sm = label_to_sm(labels=y_pred, n_classes=10)
  metric = f1_score(y_true=y_true_sm, y_pred=y_pred_sm, average='weighted')
  return metric

#################################################

def get_sm(y_true, y_pred):
  y_true_sm = label_to_sm(labels=y_true, n_classes=10)
  y_pred_sm = label_to_sm(labels=y_pred, n_classes=10)
  return y_true_sm, y_pred_sm

# %%
def get_split(path):
  myaudio = AudioSegment.from_file(path , "wav") 
  chunk_length_ms = 1500 # pydub calculates in millisec
  chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

  #Export all of the individual chunks as wav files
  paths =[]

  for i, chunk in enumerate(chunks):
      chunk_name = "chunk{0}.wav".format(i)
      paths.append(chunk_name)
      chunk.export(chunk_name, format="wav")

  return paths

##################################################

def get_spec(path):
    y, sr = librosa.load(path)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    return np.resize(S, (65, 40))

##################################################

def get_xqs(paths):
  xqs = []
  for i in range(6): #only using first 6 chunks
    t = get_spec(paths[i])
    xqs.append(t)
  return xqs

# %%
def get_probs(model, xqs):
  probs = []
  for xq in xqs:
    xq = xq.reshape((1,65,40))
    p = model.predict(xq, verbose = 0)
    probs.append(p)
  return np.array(probs)

def predict(model, xqs, num_species):
  probs = get_probs(model, xqs)
  # aggregrate
  # s = np.sum(probs, axis = 0)
  s = np.max(probs, axis = 0)
  if num_species == 2: 
    n = 2
  else:
    n = 3
  labels = np.argsort(s[0])[::-1][:n]
  return list(labels)

# %%
def test(model, df, num_species):
  y_true = list(df['class_label'])
  y_pred = []
  for i in tqdm(range(len(df))):
    path = df['path'][i]
    chunk_paths = get_split(path)
    xqs = get_xqs(chunk_paths)
    label = predict(model, xqs, num_species)
    y_pred.append(label)
  return y_true, y_pred

#########################################################

def evaluate(model, df_mix_2, df_mix_3):
  y_true_2, y_pred_2 = test(model, df_mix_2, 2)
  y_true_3, y_pred_3 = test(model, df_mix_3, 3)
  
  y_true = y_true_2 + y_true_3
  y_pred = y_pred_2 + y_pred_3
  score = get_f1_score(y_true, y_pred)
  
  return y_true, y_pred, score

# %%
y_true, y_pred, score = evaluate(model, df_mix_2, df_mix_3)
score
# Out:
# 100%|██████████| 334/334 [05:44<00:00,  1.03s/it]
# 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# 0.37424487585440536

# %%
from sklearn.metrics import classification_report

y_true, y_pred = get_sm(y_true, y_pred)
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.30      0.28        69
#            1       0.24      0.11      0.15       101
#            2       0.79      0.57      0.66       100
#            3       0.54      0.73      0.62        88
#            4       0.61      0.89      0.72       145
#            5       0.21      0.12      0.16       136
#            6       0.00      0.00      0.00        55
#            7       0.34      1.00      0.50        63
#            8       1.00      0.03      0.05       119
#            9       0.36      0.66      0.47        92
#
#    micro avg       0.44      0.44      0.44       968
#    macro avg       0.43      0.44      0.36       968
# weighted avg       0.47      0.44      0.37       968
#  samples avg       0.44      0.44      0.44       968
