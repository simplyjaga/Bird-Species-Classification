# %%
# !pip install pydub

import os
import pandas as pd
import numpy as np 
import seaborn as sns
from tqdm import tqdm

from pydub import AudioSegment
from IPython.display import Audio

import librosa
import librosa.display
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/train_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_train = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_train.shape)
df_train.sample(5)
# Out:
# (974, 2)
#                                                   path class_name
# 894  /content/drive/MyDrive/Bird/dataset/whole_data...        owl
# 546  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay
# 264  /content/drive/MyDrive/Bird/dataset/whole_data...       crow
# 558  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay
# 189  /content/drive/MyDrive/Bird/dataset/whole_data...       crow

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_train['class_label'] = df_train.apply(name_to_label, axis=1)
df_train.sample(5)
# Out:
#                                                   path class_name  class_label
# 87   /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 511  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 553  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 497  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 595  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway            4

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/validation_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_test = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_test.shape)
df_test.sample(5)
# Out:
# (104, 2)
#                                                  path class_name
# 47  /content/drive/MyDrive/Bird/dataset/whole_data...       duck
# 40  /content/drive/MyDrive/Bird/dataset/whole_data...       duck
# 59  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 89  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl
# 8   /content/drive/MyDrive/Bird/dataset/whole_data...        owl

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_test['class_label'] = df_test.apply(name_to_label, axis=1)
df_test.sample(5)
# Out:
#                                                  path class_name  class_label
# 83  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 68  /content/drive/MyDrive/Bird/dataset/whole_data...    bluejay            1
# 95  /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2
# 50  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel            0
# 3   /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6

# %%
# !pip install pydub

import os
import pandas as pd
import numpy as np 
import seaborn as sns
from tqdm import tqdm

from pydub import AudioSegment
from IPython.display import Audio

import librosa
import librosa.display
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.8/dist-packages (0.25.1)

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/train_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_train = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_train.shape)
df_train.sample(5)
# Out:
# (974, 2)
#                                                   path class_name
# 717  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe
# 354  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 276  /content/drive/MyDrive/Bird/dataset/whole_data...       crow
# 962  /content/drive/MyDrive/Bird/dataset/whole_data...        owl
# 719  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_train['class_label'] = df_train.apply(name_to_label, axis=1)
df_train.sample(5)
# Out:
#                                                   path class_name  class_label
# 114  /content/drive/MyDrive/Bird/dataset/whole_data...       duck            3
# 221  /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2
# 252  /content/drive/MyDrive/Bird/dataset/whole_data...       crow            2
# 875  /content/drive/MyDrive/Bird/dataset/whole_data...    lapwing            5
# 880  /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6

# %%
# creating the dataframe which has path to wav file and it's label

label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/train_val/validation_data'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_test = pd.DataFrame({'path': path,
                         'class_name': label})
print(df_test.shape)
df_test.sample(5)
# Out:
# (104, 2)
#                                                  path class_name
# 36  /content/drive/MyDrive/Bird/dataset/whole_data...    sparrow
# 24  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway
# 61  /content/drive/MyDrive/Bird/dataset/whole_data...  Asiankoel
# 38  /content/drive/MyDrive/Bird/dataset/whole_data...    sparrow
# 1   /content/drive/MyDrive/Bird/dataset/whole_data...        owl

# %%
# adding numerical class labels to each audio files

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
       'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

def name_to_label(x):
  cls_name = x['class_name']
  return cls_label[cls_name]

df_test['class_label'] = df_test.apply(name_to_label, axis=1)
df_test.sample(5)
# Out:
#                                                  path class_name  class_label
# 85  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 26  /content/drive/MyDrive/Bird/dataset/whole_data...     goaway            4
# 89  /content/drive/MyDrive/Bird/dataset/whole_data...    peafowl            7
# 4   /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6
# 9   /content/drive/MyDrive/Bird/dataset/whole_data...        owl            6

# %%
#train set
X_train = df_train['path']
y_train = df_train['class_label']

#test set
X_test = df_test['path']
y_test = df_test['class_label']

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((974,), (974,), (104,), (104,))

# %%
#getting mfcc features for all the data points in test and train

def get_mfcc(path):
    y, sr = librosa.load(path)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    return mfccs.T

# %%
# train data
temp = []
label = []
for i in tqdm(range(len(X_train))):
  audio_path = X_train.iloc[i]
  mfcc = get_mfcc(audio_path)
  mfcc = np.resize(mfcc, (65, 40,))
  temp.append(mfcc)
  label.append(y_train.iloc[i])

X_train_processed = np.asarray(temp)
y_train = np.asarray(label)

X_train_processed.shape, y_train.shape
# Out:
# 100%|██████████| 974/974 [04:02<00:00,  4.01it/s]
# ((974, 65, 40), (974,))

# %%
#test data
temp = []
label = []

for i in tqdm(range(len(X_test))):
  audio_path = X_test.iloc[i]
  mfcc = get_mfcc(audio_path)
  mfcc = np.resize(mfcc, (65, 40))
  temp.append(mfcc)
  label.append(y_test.iloc[i])

X_test_processed = np.asarray(temp)
y_test = np.asarray(label)

X_test_processed.shape, y_test.shape
# Out:
# 100%|██████████| 104/104 [00:27<00:00,  3.80it/s]
# ((104, 65, 40), (104,))

# %% [markdown]
# #### Modelling

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
import keras.backend as K

tf.keras.backend.clear_session()

# %%
# Add attention layer to the deep learning network
class attention(layers.Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)
 
    def build(self,input_shape):
        self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1), 
                               initializer='random_normal', trainable=True)
        self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1), 
                               initializer='zeros', trainable=True)        
        super(attention, self).build(input_shape)
 
    def call(self,x):
        # Alignment scores. Pass them through tanh function
        e = K.tanh(K.dot(x,self.W)+self.b)
        # Remove dimension of size 1
        e = K.squeeze(e, axis=-1)   
        # Compute the weights
        alpha = K.softmax(e)
        # Reshape to tensorFlow format
        alpha = K.expand_dims(alpha, axis=-1)
        # Compute the context vector
        context = x * alpha
        context = K.sum(context, axis=1)
        return context

# %%
#Create model

#input
input = layers.Input(shape=(65,40), name='input_layer')

#cnn
x = layers.Conv1D(128, (3,), activation='relu')(input)
x = layers.Conv1D(64, (3,), activation='relu')(x)
 
#lstm
x = layers.LSTM(128, return_sequences = True)(x)
x = layers.LSTM(64, return_sequences = True)(x)
x = attention()(x)
#dense
x = layers.Dense(128,'relu')(x)
x = layers.Dense(64,'relu')(x)

#output
output = layers.Dense(10, 'sigmoid', name='output_layer')(x)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 65, 40)]          0
#
#  conv1d (Conv1D)             (None, 63, 128)           15488
#
#  conv1d_1 (Conv1D)           (None, 61, 64)            24640
#
#  lstm (LSTM)                 (None, 61, 128)           98816
#
#  lstm_1 (LSTM)               (None, 61, 64)            49408
#
#  attention (attention)       (None, 64)                125
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  output_layer (Dense)        (None, 10)                650
#
# =================================================================
# Total params: 205,703
# Trainable params: 205,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile
ls = tf.keras.losses.SparseCategoricalCrossentropy()
adam = tf.keras.optimizers.Adam()
model.compile(adam, ls, metrics='accuracy')

#fitting
history = model.fit(X_train_processed, y_train, 
                    validation_data = (X_test_processed, y_test),
                    epochs = 20)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 11s 202ms/step - loss: 2.0910 - accuracy: 0.3172 - val_loss: 1.5406 - val_accuracy: 0.4423
# Epoch 2/20
# 31/31 [==============================] - 5s 156ms/step - loss: 1.0163 - accuracy: 0.6632 - val_loss: 0.5242 - val_accuracy: 0.8750
# Epoch 3/20
# 31/31 [==============================] - 5s 153ms/step - loss: 0.3388 - accuracy: 0.9014 - val_loss: 0.2534 - val_accuracy: 0.9423
# Epoch 4/20
# 31/31 [==============================] - 5s 153ms/step - loss: 0.1965 - accuracy: 0.9425 - val_loss: 0.3627 - val_accuracy: 0.9135
# Epoch 5/20
# 31/31 [==============================] - 5s 154ms/step - loss: 0.1587 - accuracy: 0.9548 - val_loss: 0.2894 - val_accuracy: 0.9231
# Epoch 6/20
# 31/31 [==============================] - 5s 155ms/step - loss: 0.1617 - accuracy: 0.9600 - val_loss: 0.2637 - val_accuracy: 0.9231
# Epoch 7/20
# 31/31 [==============================] - 5s 154ms/step - loss: 0.0858 - accuracy: 0.9743 - val_loss: 0.2280 - val_accuracy: 0.9615
# Epoch 8/20
# 31/31 [==============================] - 5s 155ms/step - loss: 0.0350 - accuracy: 0.9918 - val_loss: 0.1837 - val_accuracy: 0.9615
# Epoch 9/20
# 31/31 [==============================] - 5s 154ms/step - loss: 0.1149 - accuracy: 0.9692 - val_loss: 0.2777 - val_accuracy: 0.9327
# Epoch 10/20
# 31/31 [==============================] - 5s 156ms/step - loss: 0.0572 - accuracy: 0.9836 - val_loss: 0.1871 - val_accuracy: 0.9712
# Epoch 11/20
# 31/31 [==============================] - 5s 155ms/step - loss: 0.1912 - accuracy: 0.9435 - val_loss: 0.3039 - val_accuracy: 0.9135
# Epoch 12/20
# 31/31 [==============================] - 5s 156ms/step - loss: 0.0393 - accuracy: 0.9897 - val_loss: 0.2392 - val_accuracy: 0.9615
# Epoch 13/20
# 31/31 [==============================] - 5s 159ms/step - loss: 0.0109 - accuracy: 0.9990 - val_loss: 0.2105 - val_accuracy: 0.9712
# Epoch 14/20
# 31/31 [==============================] - 5s 157ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.2216 - val_accuracy: 0.9615
# Epoch 15/20
# 31/31 [==============================] - 5s 155ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9615
# Epoch 16/20
# 31/31 [==============================] - 5s 157ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9615
# Epoch 17/20
# 31/31 [==============================] - 5s 156ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9615
# Epoch 18/20
# 31/31 [==============================] - 5s 154ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2463 - val_accuracy: 0.9712
# Epoch 19/20
# 31/31 [==============================] - 7s 229ms/step - loss: 8.6518e-04 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9712
# Epoch 20/20
# 31/31 [==============================] - 5s 155ms/step - loss: 6.2341e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9712

# %% [markdown]
# #### Predictions

# %%
# !pip install pydub

import os 
from multiprocessing import Pool

import pandas as pd
import numpy as np

from sklearn.metrics import f1_score
from scipy.sparse import lil_matrix

import tensorflow as tf 
from tqdm import tqdm

import librosa
from pydub import AudioSegment
from pydub.utils import make_chunks
from IPython.display import Audio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.8/dist-packages (0.25.1)

# %%
#assigning numerical class labels to each bird species

cls_label = {'Asiankoel' : 0, 'bluejay': 1, 'crow': 2, 'duck': 3, 'goaway': 4, 'lapwing': 5, 'owl': 6,
             'peafowl' : 7, 'sparrow':8, 'woodpeewe':9}

########################################################

def get_class_labels(r):
  x = r['class_name']
  label_names = x.split('_')

  label_nums=[]
  for l in label_names:
    indx = cls_label[l]
    label_nums.append(indx)

  return label_nums

# %%
# creating the dataframe which has path to wav file and it's label
# 2 species test dataset
label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/mix_2'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_mix_2 = pd.DataFrame({'path': path,
                         'class_name': label})

df_mix_2['class_label'] = df_mix_2.apply(get_class_labels, axis=1)

print(df_mix_2.shape)
df_mix_2.sample(5)
# Out:
# (334, 3)
#                                                   path         class_name  \
# 247  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe_lapwing
# 107  /content/drive/MyDrive/Bird/dataset/whole_data...          duck_crow
# 166  /content/drive/MyDrive/Bird/dataset/whole_data...       duck_bluejay
# 264  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe_lapwing
# 254  /content/drive/MyDrive/Bird/dataset/whole_data...  woodpeewe_lapwing
#
#     class_label
# 247      [9, 5]
# 107      [3, 2]
# 166      [3, 1]
# 264      [9, 5]
# 254      [9, 5]

# %%
# 3 species test dataset 
label = []
path = []

root = '/content/drive/MyDrive/Bird/dataset/whole_dataset/mix_3'
for species in os.listdir(root):
    species_folder = root + '/' + species
    for audio in os.listdir(species_folder):
        audio_path = species_folder + '/' + audio
        path.append(audio_path)
        label.append(species)
        
df_mix_3 = pd.DataFrame({'path': path,
                         'class_name': label})

df_mix_3['class_label'] = df_mix_3.apply(get_class_labels, axis=1)

print(df_mix_3.shape)
df_mix_3.sample(5)
# Out:
# (100, 3)
#                                                  path  \
# 83  /content/drive/MyDrive/Bird/dataset/whole_data...
# 71  /content/drive/MyDrive/Bird/dataset/whole_data...
# 91  /content/drive/MyDrive/Bird/dataset/whole_data...
# 74  /content/drive/MyDrive/Bird/dataset/whole_data...
# 19  /content/drive/MyDrive/Bird/dataset/whole_data...
#
#                   class_name class_label
# 83    goaway_lapwing_bluejay   [4, 5, 1]
# 71  goaway_sparrow_Asiankoel   [4, 8, 0]
# 91    bluejay_peafowl_goaway   [1, 7, 4]
# 74           crow_owl_goaway   [2, 6, 4]
# 19       goaway_sparrow_crow   [4, 8, 2]

# %%
# whole test data i.e mixture of both 2 and 3 species audio files
df = pd.concat([df_mix_2, df_mix_3], ignore_index = True)
df.sample(5)
# Out:
#                                                   path  \
# 349  /content/drive/MyDrive/Bird/dataset/whole_data...
# 86   /content/drive/MyDrive/Bird/dataset/whole_data...
# 197  /content/drive/MyDrive/Bird/dataset/whole_data...
# 77   /content/drive/MyDrive/Bird/dataset/whole_data...
# 144  /content/drive/MyDrive/Bird/dataset/whole_data...
#
#                  class_name class_label
# 349  bluejay_woodpeewe_crow   [1, 9, 2]
# 86             sparrow_crow      [8, 2]
# 197       woodpeewe_sparrow      [9, 8]
# 77            owl_Asiankoel      [6, 0]
# 144         lapwing_bluejay      [5, 1]

# %%
# ref: https://www.kaggle.com/code/arailly/multi-label-f-beta-score/notebook

# metrics function

def label_to_sm(labels, n_classes):
    sm = lil_matrix((len(labels), n_classes))
    for i, label in enumerate(labels):
        sm[i, label] = 1  #eg: sm[0, [2,3]] = 1
    return sm

###############################################

def get_f1_score(y_true, y_pred):
  y_true_sm = label_to_sm(labels=y_true, n_classes=10)
  y_pred_sm = label_to_sm(labels=y_pred, n_classes=10)
  metric = f1_score(y_true=y_true_sm, y_pred=y_pred_sm, average='weighted')
  return metric

#################################################

def get_sm(y_true, y_pred):
  y_true_sm = label_to_sm(labels=y_true, n_classes=10)
  y_pred_sm = label_to_sm(labels=y_pred, n_classes=10)
  return y_true_sm, y_pred_sm

# %%
def get_split(path):
  myaudio = AudioSegment.from_file(path , "wav") 
  chunk_length_ms = 1500 # pydub calculates in millisec
  chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

  #Export all of the individual chunks as wav files
  paths =[]

  for i, chunk in enumerate(chunks):
      chunk_name = "chunk{0}.wav".format(i)
      paths.append(chunk_name)
      chunk.export(chunk_name, format="wav")

  return paths

##################################################

def get_mfcc(path):
    y, sr = librosa.load(path)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    mfccs = mfccs.T
    return np.resize(mfccs, (65, 40))

##################################################

def get_xqs(paths):
  xqs = []
  for i in range(6): #only using first 6 chunks
    t = get_mfcc(paths[i])
    xqs.append(t)
  return xqs

# %%
def get_probs(model, xqs):
  probs = []
  for xq in xqs:
    xq = xq.reshape((1,65,40))
    p = model.predict(xq, verbose = 0)
    probs.append(p)
  return np.array(probs)

def predict(model, xqs, num_species):
  probs = get_probs(model, xqs)
  # aggregrate
  # s = np.sum(probs, axis = 0)
  s = np.max(probs, axis = 0)
  if num_species == 2: 
    n = 2
  else:
    n = 3
  labels = np.argsort(s[0])[::-1][:n]
  return list(labels)

# %%
def test(model, df, num_species):
  y_true = list(df['class_label'])
  y_pred = []
  for i in tqdm(range(len(df))):
    path = df['path'][i]
    chunk_paths = get_split(path)
    xqs = get_xqs(chunk_paths)
    label = predict(model, xqs, num_species)
    y_pred.append(label)
  return y_true, y_pred

#########################################################

def evaluate(model, df_mix_2, df_mix_3):
  y_true_2, y_pred_2 = test(model, df_mix_2, 2)
  y_true_3, y_pred_3 = test(model, df_mix_3, 3)
  
  y_true = y_true_2 + y_true_3
  y_pred = y_pred_2 + y_pred_3
  score = get_f1_score(y_true, y_pred)
  
  return y_true, y_pred, score

# %%
y_true, y_pred, score = evaluate(model, df_mix_2, df_mix_3)
score
# Out:
# 100%|██████████| 334/334 [06:02<00:00,  1.08s/it]
# 100%|██████████| 100/100 [01:41<00:00,  1.02s/it]
# 0.7609512147274679

# %%
from sklearn.metrics import classification_report

y_true, y_pred = get_sm(y_true, y_pred)
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.94      0.81        69
#            1       0.76      0.67      0.72       101
#            2       0.97      0.95      0.96       100
#            3       0.92      0.77      0.84        88
#            4       0.63      0.99      0.77       145
#            5       0.82      0.91      0.86       136
#            6       0.87      0.24      0.37        55
#            7       0.82      0.95      0.88        63
#            8       0.57      0.36      0.44       119
#            9       1.00      0.78      0.88        92
#
#    micro avg       0.78      0.78      0.78       968
#    macro avg       0.81      0.76      0.75       968
# weighted avg       0.79      0.78      0.76       968
#  samples avg       0.78      0.78      0.78       968
